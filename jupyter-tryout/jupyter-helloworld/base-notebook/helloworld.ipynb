# %%
import copy
import requests
from pprint import pprint
import re

# %%
searchURL = 'https://www.carousell.com.hk/u/kylema11201/reviews/'

# %%
searchResp = requests.get(url=searchURL)

# %%
pprint(searchResp.text)
# Out:
# ('<!doctype html>\n'
#  '<html lang="zh-Hant-HK">\n'
#  '  <head>\n'
#  '    <meta charset="utf-8">\n'
#  '    \n'
#  '    \n'
#  '    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n'
#  '    <meta name="google-site-verification" '
#  'content="6r9dvBAYaV-XPXeQO1vW5a49IU9RUY0GurZzrOemxG8" />\n'
#  '    <meta name="referrer" content="strict-origin-when-cross-origin" />\n'
#  '    <link rel="icon" '
#  'href="https://mweb-cdn.karousell.com/static/favicon.ico">\n'
#  '    <link rel="apple-touch-icon" '
#  'href="https://mweb-cdn.karousell.com/static/apple-touch-icon-180.png">\n'
#  '    <link rel="preconnect" href="https://mweb-cdn.karousell.com" '
#  'crossorigin>\n'
#  '    <link rel="dns-prefetch" href="https://mweb-cdn.karousell.com" '
#  'crossorigin>\n'
#  '    <link rel="preconnect" href="https://media.karousell.com" crossorigin>\n'
#  '    <link rel="dns-prefetch" href="https://media.karousell.com" '
#  'crossorigin>\n'
#  '    <link rel="preconnect" href="https://cdn.karousell.com" crossorigin>\n'
#  '    <link rel="dns-prefetch" href="https://cdn.karousell.com" crossorigin>\n'
#  '    \n'
#  '    <link rel="dns-prefetch" href="https://www.google-analytics.com" '
#  'crossorigin>\n'
#  '    <link rel="dns-prefetch" href="https://www.googletagmanager.com" '
#  'crossorigin>\n'
#  '    <link rel="dns-prefetch" href="https://dynamic.criteo.com" crossorigin>\n'
#  '    <link rel="dns-prefetch" href="https://storage.googleapis.com" '
#  'crossorigin>\n'
#  '    <link rel="dns-prefetch" href="https://connect.facebook.net" '
#  'crossorigin>\n'
#  '    <title data-rh="true">Kyle Ma&#x27;s Reviews on Carousell Hong '
#  'Kong</title>\n'
#  '    <meta data-rh="true" content="Username: kylema11201. Rating: 5(33). 已加入 '
#  '4y 10m ago. 已認證. 好準時 即日要都得 好感動 仲要好有耐性 抵讚!!!🥲🥲" name="description"/><meta '
#  'data-rh="true" content="carousell:item" property="og:type"/><meta '
#  'data-rh="true" content="kylema11201 is on Carousell" '
#  'property="og:title"/><meta data-rh="true" '
#  'content="https://www.carousell.com.hk/u/kylema11201/reviews/" '
#  'property="og:url"/><meta data-rh="true" content="Check out kylema11201’s '
#  'listings. View on the Carousell app or download the app now." '
#  'property="og:description"/><meta data-rh="true" content="Carousell" '
#  'property="og:site_name"/><meta data-rh="true" content="379979055398817" '
#  'property="fb:app_id"/><meta data-rh="true" '
#  'content="https://media.karousell.com/media/photos/profiles/2019/07/22/kylema11201_1563810980.jpg" '
#  'property="og:image"/><meta data-rh="true" content="200" '
#  'property="og:image:width"/><meta data-rh="true" content="200" '
#  'property="og:image:height"/><meta data-rh="true" content="gallery" '
#  'name="twitter:card"/><meta data-rh="true" content="@carousell" '
#  'name="twitter:site"/><meta data-rh="true" content="kylema11201 is on '
#  'Carousell" name="twitter:title"/><meta data-rh="true" '
#  'content="https://media.karousell.com/media/photos/profiles/2019/07/22/kylema11201_1563810980.jpg" '
#  'name="twitter:image"/><meta data-rh="true" content="640" '
#  'name="twitter:image:width"/><meta data-rh="true" content="640" '
#  'name="twitter:image:height"/><meta data-rh="true" content="Check out '
#  'kylema11201’s listings. View on the Carousell app or download the app now." '
#  'name="twitter:description"/><meta data-rh="true" '
#  'content="carousell://kylema11201" '
#  'name="branch:deeplink:$deeplink_path"/><meta data-rh="true" '
#  'content="kylema11201" name="keywords"/>\n'
#  '    <link data-rh="true" '
#  'href="https://www.carousell.com.hk/u/kylema11201/reviews/" '
#  'rel="canonical"/>\n'
#  '    \n'
#  '    <link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/style-b35aeb3c75de108d5c45.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/dac96a24f33933c43d79.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/979f3ee952178620fe06.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/e6d6ba01d56a0fc10e14.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/333bf21a63b4c5afb945.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/156f181b686a81002e63.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/1304b272d12a472e3609.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/ec7fffc742a9c42f7322.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/c8141fac866e204b5a62.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/484c3ad62e2ec5e7bf43.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/5b70889c659187d4b258.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/90272df34eeaaa01926c.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/32aa73fe41009fd00488.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/4a9b413bbe73d3b83d8b.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/90f4235b0a25eeedb704.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/1bb272d3e879abdb130f.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/4cff099198fadb56a84c.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/090e0dc58e77c283cf43.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/577e64915b0f999d3150.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/08096f2470d554c64768.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/451d44e91547b87627ea.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/abc29340f018cfc10065.min.css">\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://mweb-cdn.karousell.com/build/eec495c5093c264510a4.min.css">\n'
#  '    <script>window.config = '
#  '{"assetsSmartListingsUrl":"https://sl3-cdn.karousell.com","parentDomain":"carousell.com","ssoServiceHost":"login.carousell.com","a":"_Wd\x7fMgZV,i/Kg+OuOl{l[dI[.d&m|&IYqYjk+vS","adyenScriptUrl":"https://checkoutshopper-live.adyen.com/checkoutshopper/assets/js/sdk/checkoutSecuredFields.1.5.0.min.js","copyrightYear":"2022","facebookAdmins":"574166763","facebookAppID":"379979055398817","googleOneTapClientId":"11554775814-7r66n1ftmnba4010hbrm5k2k38n4hkfg.apps.googleusercontent.com","googleRecaptchaSiteKey":"6LcX4DUdAAAAADATKpGWK5uL7t3xPuTh4zpOikRT","runtimeEnv":"production","sendbird":{"app_id":"F3CB6187-CB42-4CD1-95FC-1C46F8856006"},"siftScienceApiKey":"bd9f9b8f67","stripeApiKey":"pk_live_RucJ8dR17FAW6fXtev6teJY3","stripeMonetisationApiKeyHK":"pk_live_ze1IdKL5G9nuLgPjVlcwK5ka00Qrmeyn4G","stripeMonetisationApiKeyMY":"pk_live_szs4koQ2QmXUWEV8Fy4yzi1l00CISqPgi9","stripeMonetisationApiKeySG":"pk_live_kNUcwznrRxmxgUG2d0mdHY8U004YlBL3An","stripeTransactionsApiKeyMY":"pk_live_avgMmPE8IbqLGfgHywrB3FN500JW8YtgFx","stripeTransactionsApiKeySG":"pk_live_XSo8cXHIyP0wVcDAJAyrZhN3","twitterAndroidAppID":"com.thecarousell.Carousell","twitterIOSAppID":"id548607187"};</script>\n'
#  '    <meta name="branch:deeplink:safari-on-ios" content=false />\n'
#  '  </head>\n'
#  '  <body>\n'
#  '    <div id="root"><div class="D_nu D_rS M_mm D_sp" '
#  'style="padding-bottom:0px;padding-top:104px"><header class="D_rU M_mo D_sr " '
#  'style="margin-top:0px"><button class="D_tc M_mQ D_ty D_tp M_nc D_tk M_mX '
#  'D_tF D_rX M_mr" tabindex="0" type="button">Skip to content</button><div '
#  'class="D_sb M_me"><div class="D_se M_mg"><div class="D_sf M_mh"><div '
#  'class="D_sg M_mi"><a aria-label="Carousell logo" class="D_sh M_mj D_qi M_lI" '
#  'href="/"><svg aria-label="Carousell logo" height="20" viewBox="0 0 80 80" '
#  'width="20" xmlns="http://www.w3.org/2000/svg"><g fill="none" '
#  'fill-rule="evenodd"><path d="M69.57 6.55V3.69A3.69 3.69 0 0065.87 '
#  '0h-9.3a3.69 3.69 0 00-3.7 3.7v2.04H15.05C10.21 5.74 3 8.94 3 17.79v49.83c0 '
#  '4.85 3.21 12.06 12.05 12.06H64.9c4.85 0 12.05-3.21 '
#  '12.05-12.06V17.8c0-3.87-2.05-9.23-7.37-11.24" fill="#ffffff"></path><path '
#  'd="M63.64 40.5h-6.1a2.2 2.2 0 100 4.42h6.1a2.21 2.21 0 '
#  '100-4.42m-9.63-4.04a2.2 2.2 0 002.91 1.12l5.57-2.48a2.2 2.2 0 '
#  '10-1.8-4.04l-5.56 2.48A2.2 2.2 0 0054 36.46m-.64-5.33l4.08-4.53a2.2 2.2 0 '
#  '10-3.28-2.96l-4.08 4.53a2.2 2.2 0 00.16 3.12 2.2 2.2 0 003.12-.16" '
#  'fill="#2c2c2d"></path><path d="M47.5 58.74a2.2 2.2 0 00-2.78-1.42 15.37 '
#  '15.37 0 11-4.75-29.97 15.37 15.37 0 014.75.75 2.21 2.21 0 '
#  '002.78-1.42l1.89-5.8a2.21 2.21 0 00-1.42-2.78 25.87 25.87 0 00-8-1.27 25.88 '
#  '25.88 0 108 50.5 2.2 2.2 0 001.42-2.8l-1.89-5.8" fill="#2c2c2d"></path><path '
#  'd="M53.37 54.29a2.21 2.21 0 00-3.28 2.96l4.08 4.53a2.21 2.21 0 '
#  '003.28-2.96l-4.08-4.53m9.13-3.97l-5.58-2.48a2.21 2.21 0 00-1.8 4.03l5.58 '
#  '2.49a2.21 2.21 0 001.8-4.04" fill="#2c2c2d"></path></g></svg></a><div '
#  'class="D_si M_mk"></div><div class="D_QN M_He D_QP M_Hg" '
#  'style="height:40px"><span class="D_qk M_lK D_pQ M_lG D_ql M_lL D_qo M_lO '
#  'D_qq M_lQ D_qu M_lU D_qw M_lW D_rB">汽車及樓宇</span></div><div class="D_QN M_He '
#  'D_QP M_Hg" style="height:40px"><span class="D_qk M_lK D_pQ M_lG D_ql M_lL '
#  'D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_rB">流行時尚</span></div><div '
#  'class="D_QN M_He D_QP M_Hg" style="height:40px"><span class="D_qk M_lK D_pQ '
#  'M_lG D_ql M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW '
#  'D_rB">傢俬及家品</span></div><div class="D_QN M_He D_QP M_Hg" '
#  'style="height:40px"><span class="D_qk M_lK D_pQ M_lG D_ql M_lL D_qo M_lO '
#  'D_qq M_lQ D_qu M_lU D_qw M_lW D_rB">電子產品</span></div><div class="D_QN M_He '
#  'D_QP M_Hg" style="height:40px"><span class="D_qk M_lK D_pQ M_lG D_ql M_lL '
#  'D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_rB">興趣及遊戲</span></div><div '
#  'class="D_QN M_He D_QP M_Hg" style="height:40px"><span class="D_qk M_lK D_pQ '
#  'M_lG D_ql M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW '
#  'D_rB">工作及服務</span></div><div class="D_QN M_He D_QP M_Hg" '
#  'style="height:40px"><span class="D_qk M_lK D_pQ M_lG D_ql M_lL D_qo M_lO '
#  'D_qq M_lQ D_qu M_lU D_qw M_lW D_rB">其他</span></div><div class="D_QN M_He '
#  'D_QP M_Hg" style="height:40px"><span class="D_qk M_lK D_pQ M_lG D_ql M_lL '
#  'D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_rB">留家抗疫精選</span></div></div><div '
#  'class="D_sj M_ml"><a class="D_Ra M_Gg D_QY M_Ge D_Ey M_sg" href="/signup" '
#  'rel="noopener noreferrer"><p class="D_qk M_lK D_pQ M_lG D_ql M_lL D_qo M_lO '
#  'D_qq M_lQ D_qu M_lU D_qx M_lX D_rB">注册</p></a><a class="D_Ra M_Gg D_QY M_Ge '
#  'D_Ey M_sg" href="/login" rel="noopener noreferrer"><p class="D_qk M_lK D_pQ '
#  'M_lG D_ql M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qx M_lX '
#  'D_rB">登入</p></a></div></div></div></div><div class="D_sB M_ms"><div '
#  'class="D_sF M_mv"><a class="D_Rt M_Gy D_qi M_lI" href="/"><img '
#  'alt="Carousell logo" class="D_ams M_Za" style="height:32px;width:auto" '
#  'loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/carousell-logo-title-2Nnf7YFiNk.svg" '
#  'height="80" width="416"/></a><div class="D_alb M_Wz" role="wrapper"><form '
#  'aria-label="form" class="D_alf M_WB"><div class="D_xo M_uM D_alg M_WC" '
#  'role="dropdown"><button class="D_tc M_mQ D_ty D_tq M_ne D_tl M_mY D_tB D_xp '
#  'M_uN D_alh M_WE" type="button"><div class="D_xr M_uP"><span class="D_qk M_lK '
#  'D_pP M_lF D_ql M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_xs M_uQ '
#  'D_rA">商品</span></div><svg class="D_Km M_rP D_Ko M_rR" fill="#57585a" '
#  'height="24" viewBox="0 0 24 24" width="24" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M9.29 15.88L13.17 12 9.29 '
#  '8.12c-.39-.39-.39-1.02 0-1.41.39-.39 1.02-.39 1.41 0l4.59 4.59c.39.39.39 '
#  '1.02 0 1.41L10.7 17.3c-.39.39-1.02.39-1.41 0-.38-.39-.39-1.03 '
#  '0-1.42z"></path></svg></button></div><div class="D_alk M_WH"></div><div '
#  'class="D_uK M_oi D_alm M_WJ"><div class="D_uL M_oj D_uv D_aln M_WK"><div '
#  'class="D_uN M_ol"><input type="search" class="D_uQ M_oo D_uR M_op D_uC D_alo '
#  'M_WL" placeholder="搜尋商品或用戶" spellcheck="false" '
#  'value=""/></div></div></div><button class="D_tc M_mQ D_ty D_tq M_ne D_tv '
#  'M_nj D_alp M_WM" role="submitButton" type="submit"><svg class="D_Sq M_tk '
#  'D_alr M_WO" viewBox="0 0 24 24" '
#  'xmlns="http://www.w3.org/2000/svg"><title>Search Icon</title><path '
#  'd="M15.618 17.032a9 9 0 1 1 1.414-1.414l5.675 5.675a1 1 0 0 1-1.414 '
#  '1.414l-5.675-5.675zm-.701-2.05a1.017 1.017 0 0 1 .065-.065 7 7 0 1 '
#  '0-.066.066z" fill="#57585a"></path></svg></button></form></div></div><div '
#  'class="D_sO M_mE"><div class="D_sP M_mF"><a class="D_sQ M_mG D_uf D_ua M_rC '
#  'D_qi M_lI" href="/sell/"><span class="D_qk M_lK D_pQ M_lG D_ql M_lL D_qo '
#  'M_lO D_qq M_lQ D_qu M_lU D_qx M_lX '
#  'D_rA">賣嘢</span></a></div></div></div></header><main id="main" '
#  'tabindex="-1"><div class="D_og"><div class="D_oe"><div class="D_nv '
#  'D_nw"></div><div class="D_nv D_ny"><div class="D_nE"></div><div '
#  'class="D_nz"><div class="D_yN M_GQ  D_Rr"><a class="D_yQ M_GT D_zk D_qi '
#  'M_lI" href="/u/kylema11201/"><button class="D_tc M_mQ D_ty D_tq M_ne D_tw '
#  'M_nk D_yP M_GS" type="button"><div class="D_yS M_GV"><p class="D_qk M_lK '
#  'D_pP M_lF D_ql M_lL D_qo M_lO D_qq M_lQ D_qt M_lT D_qw M_lW D_zl D_rA" '
#  'title="商品">商品</p></div></button></a><a class="D_yQ M_GT D_zk D_yU M_GX D_yW '
#  'M_GZ D_qi M_lI" href="/u/kylema11201/reviews/"><button class="D_tc M_mQ D_ty '
#  'D_tq M_ne D_tw M_nk D_yP M_GS" type="button"><div class="D_yS M_GV"><p '
#  'class="D_qk M_lK D_pG M_lw D_ql M_lL D_qo M_lO D_qq M_lQ D_qt M_lT D_qx M_lX '
#  'D_zl D_rA" title="評論">評論</p></div></button></a></div><div class="D_ok"><div '
#  'class="D_nB"><button class="D_tc M_mQ D_ty D_tq M_ne D_tl M_mY D_tB" '
#  'type="button">Follow</button></div><button class="D_tc M_mQ D_ty D_tq M_ne '
#  'D_tv M_nj" type="button" data-testid="profile-actions-btn-icon"><svg '
#  'class="" height="16" viewBox="0 0 16 16" width="16" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M6.95 13.45a1.44 1.44 0 0 1 2.1 '
#  '0 1.44 1.44 0 0 1 0 2.1 1.44 1.44 0 0 1-2.1 0 1.44 1.44 0 0 1 '
#  '0-2.1zm0-6a1.44 1.44 0 0 1 2.1 0 1.44 1.44 0 0 1 0 2.1 1.44 1.44 0 0 1-2.1 0 '
#  '1.44 1.44 0 0 1 0-2.1zm2.1-3.9a1.44 1.44 0 0 1-2.1 0 1.44 1.44 0 0 1 0-2.1 '
#  '1.44 1.44 0 0 1 2.1 0 1.44 1.44 0 0 1 0 2.1z" fill="#57585a" '
#  'fill-rule="nonzero"></path></svg></button></div></div></div><div '
#  'class="D_nF"><div class="D_nG"><div class="D_AZ M_uu"><span class="D_xj M_pO '
#  'D_nH D_Ba M_uv D_Bk M_uE D_xk M_pP"><img alt="" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/profiles/2019/07/22/kylema11201_1563810980.jpg" '
#  'title=""/></span></div><h2 class="D_tL M_nr D_pP M_lF D_tQ M_nw D_tS M_ny '
#  'D_tW">Kyle Ma</h2><p class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qr '
#  'M_lR D_qu M_lU D_qw M_lW D_rA">@<!-- -->kylema11201</p><div class="D_nS"><p '
#  'class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW '
#  'D_rA">5.0</p><div class="D_Fn M_Wf D_nU" role="img" aria-label="5 '
#  'stars"><div class="D_Fq M_Wi D_Fs M_Wk"><svg class="" fill="#008f79" '
#  'fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fq M_Wi D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fq M_Wi D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fq M_Wi D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fq M_Wi D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div></div><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_nU D_nV D_rA">(33)</p><svg '
#  'class="" fill="#57585a" height="24" viewBox="0 0 24 24" width="24" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M9.29 15.88L13.17 12 9.29 '
#  '8.12c-.39-.39-.39-1.02 0-1.41.39-.39 1.02-.39 1.41 0l4.59 4.59c.39.39.39 '
#  '1.02 0 1.41L10.7 17.3c-.39.39-1.02.39-1.41 0-.38-.39-.39-1.03 '
#  '0-1.42z"></path></svg></div><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rB">Hong Kong<!-- --> \xa0\xa0∙\xa0\xa0 '
#  '<!-- -->已加入 4y 10m</p><div class="D_nN"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_nO D_rB">已認證</p><span '
#  'class="D_xj M_pO D_nP D_xl M_pQ "><img alt="" class="D_xm M_pR" '
#  'crossorigin="anonymous" '
#  'src="https://mweb-cdn.karousell.com/build/verification-facebook-3Y1Xs4Ri26.svg" '
#  'title=""/></span><span class="D_xj M_pO D_nP D_xl M_pQ "><img alt="" '
#  'class="D_xm M_pR" crossorigin="anonymous" '
#  'src="https://mweb-cdn.karousell.com/build/verification-email-QvlRIiMUCh.svg" '
#  'title=""/></span><span class="D_xj M_pO D_nP D_xl M_pQ "><img alt="" '
#  'class="D_xm M_pR" crossorigin="anonymous" '
#  'src="https://mweb-cdn.karousell.com/build/verification-mobile-2iJwuSTuFi.svg" '
#  'title=""/></span></div><div class="D_nN"><span class="D_xj M_pO D_nQ D_xl '
#  'M_pQ "><img alt="" class="D_xm M_pR" crossorigin="anonymous" '
#  'src="https://mweb-cdn.karousell.com/build/response-rate-h-1v83pbBk4q.svg" '
#  'title=""/></span><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_nR D_rB">非常良好回覆率</p></div><div class="D_nX"><a '
#  'class="D_nY D_ue D_qi M_lI" href="/u/kylema11201/followers/"><p class="D_qk '
#  'M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_ui D_ub '
#  'M_rE D_rB">54 Followers </p></a><a class="D_nY D_ue D_qi M_lI" '
#  'href="/u/kylema11201/following/"><p class="D_qk M_lK D_pN M_lC D_ql M_lL '
#  'D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_ui D_ub M_rE D_rB">12 Follow 緊 '
#  '</p></a></div><div></div></div><div class="D_nZ"><div class="D_pS D_tG M_nm '
#  'D_tI M_no"><div class="D_pT"><h3 class="D_tL M_nr D_pP M_lF D_tQ M_nw D_tT '
#  'M_nz D_tX">評論</h3><div class="D_xo M_uM D_pZ" role="dropdown"><button '
#  'class="D_tc M_mQ D_ty D_tq M_ne D_tl M_mY D_tB D_xp M_uN" '
#  'type="button"><span class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qq M_lQ '
#  'D_qu M_lU D_qw M_lW D_xE M_vc D_rB">Sort by</span><div class="D_xr '
#  'M_uP"><span class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qq M_lQ D_qu '
#  'M_lU D_qw M_lW D_xs M_uQ D_rA">最新</span></div><svg class="D_Km M_rP D_Ko '
#  'M_rR" fill="#57585a" height="24" viewBox="0 0 24 24" width="24" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M9.29 15.88L13.17 12 9.29 '
#  '8.12c-.39-.39-.39-1.02 0-1.41.39-.39 1.02-.39 1.41 0l4.59 4.59c.39.39.39 '
#  '1.02 0 1.41L10.7 17.3c-.39.39-1.02.39-1.41 0-.38-.39-.39-1.03 '
#  '0-1.42z"></path></svg></button></div></div><div class="D_pV"><div '
#  'class="D_NM M_CP"><div class="D_NL M_CO"><h1 class="D_tL M_nr D_pP M_lF D_tQ '
#  'M_nw D_tT M_nz D_tU M_n_ D_tV">5.00</h1><div class="D_Fn M_Wf " role="img" '
#  'aria-label="5 stars"><div class="D_Fp M_Wh D_Fs M_Wk"><svg class="" '
#  'fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div></div><span class="D_qk M_lK D_pL M_lA '
#  'D_ql M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rB">(33 '
#  '評價)</span></div><div class="D_NQ M_CT"><div class="D_NR M_CU"><span '
#  'class="D_xj M_pO D_NS M_CV D_xl M_pQ "><img alt="user-compliments" '
#  'class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/review_compliments/for-buyer-default/fast-and-decisive.png" '
#  'title=""/></span><p class="D_qk M_lK D_pL M_lA D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_rB">1</p></div><div class="D_NR M_CU"><span '
#  'class="D_xj M_pO D_NS M_CV D_xl M_pQ "><img alt="user-compliments" '
#  'class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/review_compliments/for-seller-default/unique-listing.png" '
#  'title=""/></span><p class="D_qk M_lK D_pL M_lA D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_rB">2</p></div><div class="D_NR M_CU"><span '
#  'class="D_xj M_pO D_NS M_CV D_xl M_pQ "><img alt="user-compliments" '
#  'class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/review_compliments/for-seller-default/goes-the-extra-mile.png" '
#  'title=""/></span><p class="D_qk M_lK D_pL M_lA D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_rB">3</p></div><div class="D_NR M_CU"><span '
#  'class="D_xj M_pO D_NS M_CV D_xl M_pQ "><img alt="user-compliments" '
#  'class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/review_compliments/for-seller-default/knows-their-stuff.png" '
#  'title=""/></span><p class="D_qk M_lK D_pL M_lA D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_rB">7</p></div><div class="D_NR M_CU"><span '
#  'class="D_xj M_pO D_NS M_CV D_xl M_pQ "><img alt="user-compliments" '
#  'class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/review_compliments/for-seller-default/amazing-chat-seller.png" '
#  'title=""/></span><p class="D_qk M_lK D_pL M_lA D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_rB">5</p></div></div></div><div class="D_Nl '
#  'M_Cj"><button aria-pressed="true" class="D_Cj M_wN D_Ck M_wO D_Cm M_wQ" '
#  'type="button"><span class="D_qk M_lK D_pH M_lx D_ql M_lL D_qo M_lO D_qq M_lQ '
#  'D_qu M_lU D_qw M_lW D_rB">全部</span></button><button aria-pressed="false" '
#  'class="D_Cj M_wN D_Cm M_wQ" type="button"><span class="D_qk M_lK D_pP M_lF '
#  'D_ql M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW '
#  'D_rB">來自買家</span></button><button aria-pressed="false" class="D_Cj M_wN D_Cm '
#  'M_wQ" type="button"><span class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO '
#  'D_qq M_lQ D_qu M_lU D_qw M_lW D_rB">來自賣家</span></button></div></div><ul '
#  'class="D_pW"><li class="D_Sr M_wR"><div class="D_Ss M_wS"><div class="D_Np '
#  'M_Cm"><div class="D_AZ M_uu"><span class="D_xj M_pO D_Ba M_uv D_Bg M_u_ D_xl '
#  'M_pQ D_Bc M_ux D_xk M_pP"><img alt="" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/profiles/2022/12/30/meisthebes62781_1672364733_70efa154.jpg" '
#  'title=""/></span></div><div class="D_Nq M_Cn"><div class="D_Nr M_Co"><div '
#  'class="D_Nu M_Cr"><a class="D_ue D_qi M_lI" data-testid="reviewr-name" '
#  'href="/u/meisthebes62781/"><span class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_uc M_rF '
#  'D_rA">meisthebes62781</span></a> . <span>review from buyer</span> <span '
#  'class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW '
#  'D_rB">24 小時前</span></div><div class="D_Fn M_Wf " data-testid="star-rating" '
#  'role="img" aria-label="5 stars"><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div></div><p class="D_qk M_lK D_pP M_lF D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Ns M_Cp D_rA" '
#  'data-testid="feedback-review">好準時 即日要都得 好感動 仲要好有耐性 抵讚!!!🥲🥲</p><div '
#  'class="D_ak_ M_Ws D_akA M_Wt"><span class="D_xj M_pO D_akB M_Wu D_xl M_pQ '
#  '"><img alt="" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/products/2022/8/18/programming_it_services_coding_1660794582_0068e15e_thumbnail" '
#  'title=""/></span><div class="D_akE M_Ww"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_akC M_Wv D_rB">Programming IT '
#  'CS Assignment 功課 補習 各類服務  C++ Python Java R Matlab C# 編程 教學 Coding '
#  'STEM</p><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR D_qu '
#  'M_lU D_qw M_lW D_rB">HK$0</p></div></div></div></div></div></div></li><li '
#  'class="D_Sr M_wR"><div class="D_Ss M_wS"><div class="D_Np M_Cm"><div '
#  'class="D_AZ M_uu"><span class="D_xj M_pO D_Ba M_uv D_Bg M_u_ D_xl M_pQ D_Bc '
#  'M_ux D_xk M_pP"><img alt="" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/profiles/default.png" '
#  'title=""/></span></div><div class="D_Nq M_Cn"><div class="D_Nr M_Co"><div '
#  'class="D_Nu M_Cr"><a class="D_ue D_qi M_lI" data-testid="reviewr-name" '
#  'href="/u/matthewcheuk/"><span class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO '
#  'D_qq M_lQ D_qu M_lU D_qw M_lW D_uc M_rF D_rA">matthewcheuk</span></a> . '
#  '<span>review from buyer</span> <span class="D_qk M_lK D_pN M_lC D_ql M_lL '
#  'D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rB">3 天前</span></div><div '
#  'class="D_Fn M_Wf " data-testid="star-rating" role="img" aria-label="5 '
#  'stars"><div class="D_Fp M_Wh D_Fs M_Wk"><svg class="" fill="#008f79" '
#  'fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div></div><p class="D_qk M_lK D_pP M_lF D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Ns M_Cp D_rA" '
#  'data-testid="feedback-review">好好人 做嘢寫 code 好快手 更重要嘅係好耐心咁解釋每一行 code 嘅用途 d '
#  'function 有咩用得唔用得 等我呢個唔識 programming 嘅獲益良多 做嘅嘢遠遠唔止寫份 code 咁簡單</p><div '
#  'class="D_ak_ M_Ws D_akA M_Wt"><span class="D_xj M_pO D_akB M_Wu D_xl M_pQ '
#  '"><img alt="" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/products/2022/8/18/programming_it_services_coding_1660794582_0068e15e_thumbnail" '
#  'title=""/></span><div class="D_akE M_Ww"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_akC M_Wv D_rB">Programming IT '
#  'CS Assignment 功課 補習 各類服務  C++ Python Java R Matlab C# 編程 教學 Coding '
#  'STEM</p><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR D_qu '
#  'M_lU D_qw M_lW D_rB">HK$0</p></div></div></div></div></div></div></li><li '
#  'class="D_Sr M_wR"><div class="D_Ss M_wS"><div class="D_Np M_Cm"><div '
#  'class="D_AZ M_uu"><span class="D_xj M_pO D_Ba M_uv D_Bg M_u_ D_xl M_pQ D_Bc '
#  'M_ux D_xk M_pP"><img alt="" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/profiles/2018/07/18/pkpkll1_1531918921.jpg" '
#  'title=""/></span></div><div class="D_Nq M_Cn"><div class="D_Nr M_Co"><div '
#  'class="D_Nu M_Cr"><a class="D_ue D_qi M_lI" data-testid="reviewr-name" '
#  'href="/u/pkpkll1/"><span class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qq '
#  'M_lQ D_qu M_lU D_qw M_lW D_uc M_rF D_rA">pkpkll1</span></a> . <span>review '
#  'from buyer</span> <span class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr '
#  'M_lR D_qu M_lU D_qw M_lW D_rB">14 天前</span></div><div class="D_Fn M_Wf " '
#  'data-testid="star-rating" role="img" aria-label="5 stars"><div class="D_Fp '
#  'M_Wh D_Fs M_Wk"><svg class="" fill="#008f79" fill-rule="nonzero" viewBox="0 '
#  '0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 '
#  '1 0 0 1 1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 '
#  '0 0 1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 '
#  '1 0 0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div></div><p class="D_qk M_lK D_pP M_lF D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Ns M_Cp D_rA" '
#  'data-testid="feedback-review">態度良好，有禮</p><div class="D_ak_ M_Ws D_akA '
#  'M_Wt"><span class="D_xj M_pO D_akB M_Wu D_xl M_pQ "><img alt="" class="D_xm '
#  'M_pR" '
#  'src="https://media.karousell.com/media/photos/products/2022/8/18/programming_it_services_coding_1660794582_0068e15e_thumbnail" '
#  'title=""/></span><div class="D_akE M_Ww"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_akC M_Wv D_rB">Programming IT '
#  'CS Assignment 功課 補習 各類服務  C++ Python Java R Matlab C# 編程 教學 Coding '
#  'STEM</p><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR D_qu '
#  'M_lU D_qw M_lW D_rB">HK$0</p></div></div></div></div></div></div></li><li '
#  'class="D_Sr M_wR"><div class="D_Ss M_wS"><div class="D_Np M_Cm"><div '
#  'class="D_AZ M_uu"><span class="D_xj M_pO D_Ba M_uv D_Bg M_u_ D_xl M_pQ D_Bc '
#  'M_ux D_xk M_pP"><img alt="" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/profiles/2022/10/25/lin199903126093_1666698680_5ea7a9f1.jpg" '
#  'title=""/></span></div><div class="D_Nq M_Cn"><div class="D_Nr M_Co"><div '
#  'class="D_Nu M_Cr"><a class="D_ue D_qi M_lI" data-testid="reviewr-name" '
#  'href="/u/lin199903126093/"><span class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_uc M_rF '
#  'D_rA">lin199903126093</span></a> . <span>review from buyer</span> <span '
#  'class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW '
#  'D_rB">18 天前</span></div><div class="D_Fn M_Wf " data-testid="star-rating" '
#  'role="img" aria-label="5 stars"><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div></div><div class="D_NC M_C_"><div '
#  'class="D_NE M_CA"><span class="D_xj M_pO D_NF M_CB D_xl M_pQ "><img '
#  'alt="Amazing chat" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/review_compliments/for-seller-default/amazing-chat-seller.png" '
#  'title=""/></span><p class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_rB">Amazing chat</p></div><div class="D_NE M_CA"><span '
#  'class="D_xj M_pO D_NF M_CB D_xl M_pQ "><img alt="Goes the extra mile" '
#  'class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/review_compliments/for-seller-default/goes-the-extra-mile.png" '
#  'title=""/></span><p class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_rB">Goes the extra mile</p></div><div class="D_NE '
#  'M_CA"><span class="D_xj M_pO D_NF M_CB D_xl M_pQ "><img alt="Knows their '
#  'stuff" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/review_compliments/for-seller-default/knows-their-stuff.png" '
#  'title=""/></span><p class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_rB">Knows their stuff</p></div></div><p class="D_qk '
#  'M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Ns M_Cp '
#  'D_rA" data-testid="feedback-review">Great work </p><div class="D_ak_ M_Ws '
#  'D_akA M_Wt"><span class="D_xj M_pO D_akB M_Wu D_xl M_pQ "><img alt="" '
#  'class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/products/2022/8/18/programming_it_services_coding_1660794582_0068e15e_thumbnail" '
#  'title=""/></span><div class="D_akE M_Ww"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_akC M_Wv D_rB">Programming IT '
#  'CS Assignment 功課 補習 各類服務  C++ Python Java R Matlab C# 編程 教學 Coding '
#  'STEM</p><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR D_qu '
#  'M_lU D_qw M_lW D_rB">HK$0</p></div></div></div></div></div></div></li><li '
#  'class="D_Sr M_wR"><div class="D_Ss M_wS"><div class="D_Np M_Cm"><div '
#  'class="D_AZ M_uu"><span class="D_xj M_pO D_Ba M_uv D_Bg M_u_ D_xl M_pQ D_Bc '
#  'M_ux D_xk M_pP"><img alt="" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/profiles/2020/12/21/bellaleung03_1608520262.jpg" '
#  'title=""/></span></div><div class="D_Nq M_Cn"><div class="D_Nr M_Co"><div '
#  'class="D_Nu M_Cr"><a class="D_ue D_qi M_lI" data-testid="reviewr-name" '
#  'href="/u/bellaleung03/"><span class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO '
#  'D_qq M_lQ D_qu M_lU D_qw M_lW D_uc M_rF D_rA">bellaleung03</span></a> . '
#  '<span>review from buyer</span> <span class="D_qk M_lK D_pN M_lC D_ql M_lL '
#  'D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rB">20 天前</span></div><div '
#  'class="D_Fn M_Wf " data-testid="star-rating" role="img" aria-label="5 '
#  'stars"><div class="D_Fp M_Wh D_Fs M_Wk"><svg class="" fill="#008f79" '
#  'fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div></div><p class="D_qk M_lK D_pP M_lF D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Ns M_Cp D_rA" '
#  'data-testid="feedback-review">推薦</p></div></div></div></div></li><li '
#  'class="D_Sr M_wR"><div class="D_Ss M_wS"><div class="D_Np M_Cm"><div '
#  'class="D_AZ M_uu"><span class="D_xj M_pO D_Ba M_uv D_Bg M_u_ D_xl M_pQ D_Bc '
#  'M_ux D_xk M_pP"><img alt="" class="D_xm M_pR" '
#  'src="https://media.karousell.com/media/photos/profiles/default.png" '
#  'title=""/></span></div><div class="D_Nq M_Cn"><div class="D_Nr M_Co"><div '
#  'class="D_Nu M_Cr"><a class="D_ue D_qi M_lI" data-testid="reviewr-name" '
#  'href="/u/klamng_/"><span class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qq '
#  'M_lQ D_qu M_lU D_qw M_lW D_uc M_rF D_rA">klamng_</span></a> . <span>review '
#  'from buyer</span> <span class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr '
#  'M_lR D_qu M_lU D_qw M_lW D_rB">25 天前</span></div><div class="D_Fn M_Wf " '
#  'data-testid="star-rating" role="img" aria-label="5 stars"><div class="D_Fp '
#  'M_Wh D_Fs M_Wk"><svg class="" fill="#008f79" fill-rule="nonzero" viewBox="0 '
#  '0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 '
#  '1 0 0 1 1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 '
#  '0 0 1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 '
#  '1 0 0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div><div class="D_Fp M_Wh D_Fs M_Wk"><svg '
#  'class="" fill="#008f79" fill-rule="nonzero" viewBox="0 0 32 32" '
#  'xmlns="http://www.w3.org/2000/svg"><path d="M11.01 10.54l4.1-8.3a1 1 0 0 1 '
#  '1.79 0l4.09 8.3 9.15 1.33a1 1 0 0 1 .56 1.7l-6.63 6.46 1.57 9.11a1 1 0 0 '
#  '1-1.45 1.06L16 25.9l-8.19 4.3a1 1 0 0 1-1.45-1.06l1.57-9.11-6.63-6.46a1 1 0 '
#  '0 1 .56-1.7L11 10.54z" stroke="#008f79" '
#  'stroke-width="2"></path></svg></div></div><div class="D_NC M_C_"><div '
#  'class="D_NE M_CA"><span class="D_xj M_pO D_NF M_CB D_xl M_pQ "><img '
#  'alt="Knows their stuff" class="D_xm M_pR" '
# ...
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">女裝</p></a><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/luxury-20/" rel="noopener '
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">名牌</p></a><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/men-s-fashion-3/" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">男裝</p></a><a class="D_xT M_wM D_Ey M_sg" '
#  'href="/categories/beauty-personal-care-11/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">美容＆化妝品</p></a></div></div><div '
#  'class="D_TI M_Rw D_xR M_wK"><div class="D_xS M_wL"><p class="D_qk M_lK D_pP '
#  'M_lF D_ql M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qx M_lX D_rC">其他</p><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/everything-else-16/" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">其他</p></a><a class="D_xT M_wM D_Ey M_sg" '
#  'href="/categories/community-26/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">社群</p></a><a class="D_xT M_wM D_Ey '
#  'M_sg" href="/categories/preorders-65/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">預購</p></a><a class="D_xT M_wM D_Ey '
#  'M_sg" href="/categories/looking-for-21/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">徵收</p></a></div></div></div><div '
#  'class="D_TH M_Rv "><div class="D_TI M_Rw D_xR M_wK"><div class="D_xS '
#  'M_wL"><p class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qr M_lR D_qu M_lU '
#  'D_qx M_lX D_rC">傢俬及家品</p><a class="D_xT M_wM D_Ey M_sg" '
#  'href="/categories/furniture-home-living-13/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">傢俬＆家居</p></a><a class="D_xT M_wM '
#  'D_Ey M_sg" href="/categories/babies-kids-19/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">兒童＆孕婦用品</p></a><a class="D_xT M_wM '
#  'D_Ey M_sg" href="/categories/health-nutrition-5642/" rel="noopener '
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">健康及營養食用品</p></a><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/food-drinks-103/" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">嘢食 &amp; '
#  '嘢飲</p></a><a class="D_xT M_wM D_Ey M_sg" href="/categories/pet-supplies-29/" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">寵物用品</p></a></div></div><div class="D_TI M_Rw D_xR M_wK"><div '
#  'class="D_xS M_wL"><p class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qr '
#  'M_lR D_qu M_lU D_qx M_lX D_rC">留家抗疫精選</p><a class="D_xT M_wM D_Ey M_sg" '
#  'href="/categories/furniture-home-living-13/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">傢俬＆家居</p></a><a class="D_xT M_wM '
#  'D_Ey M_sg" href="/categories/computers-tech-461/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">電腦＆科技</p></a><a class="D_xT M_wM '
#  'D_Ey M_sg" href="/categories/video-gaming-531/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">電子遊戲</p></a><a class="D_xT M_wM '
#  'D_Ey M_sg" href="/categories/tv-home-appliances-5462/" rel="noopener '
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">家庭電器</p></a><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/sports-equipment-10/" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">運動產品</p></a><a class="D_xT M_wM D_Ey M_sg" '
#  'href="/categories/pet-supplies-29/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">寵物用品</p></a><a class="D_xT M_wM '
#  'D_Ey M_sg" href="/services/h-1758" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">服務</p></a></div></div></div><div '
#  'class="D_TH M_Rv "><div class="D_TI M_Rw D_xR M_wK"><div class="D_xS '
#  'M_wL"><p class="D_qk M_lK D_pP M_lF D_ql M_lL D_qo M_lO D_qr M_lR D_qu M_lU '
#  'D_qx M_lX D_rC">電子產品</p><a class="D_xT M_wM D_Ey M_sg" '
#  'href="/categories/computers-tech-461/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">電腦＆科技</p></a><a class="D_xT M_wM '
#  'D_Ey M_sg" href="/categories/video-gaming-531/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">電子遊戲</p></a><a class="D_xT M_wM '
#  'D_Ey M_sg" href="/categories/mobile-phones-gadgets-462/" rel="noopener '
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">手提電話</p></a><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/audio-459/" rel="noopener '
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">音響器材</p></a><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/photography-6/" rel="noopener '
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">攝影器材</p></a><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/tv-home-appliances-5462/" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">家庭電器</p></a></div></div></div><div class="D_TH M_Rv "><div class="D_TI '
#  'M_Rw D_xR M_wK"><div class="D_xS M_wL"><p class="D_qk M_lK D_pP M_lF D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qx M_lX D_rC">興趣及遊戲</p><a class="D_xT '
#  'M_wM D_Ey M_sg" href="/categories/toys-games-12/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">玩具 &amp; 遊戲類</p></a><a class="D_xT '
#  'M_wM D_Ey M_sg" href="/categories/music-media-14/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">音樂樂器 &amp; 配件</p></a><a class="D_xT '
#  'M_wM D_Ey M_sg" href="/categories/books-magazines-5/" rel="noopener '
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">書本 &amp; '
#  '文具</p></a><a class="D_xT M_wM D_Ey M_sg" '
#  'href="/categories/stationery-craft-8/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">手作＆自家設計</p></a><a class="D_xT M_wM '
#  'D_Ey M_sg" href="/categories/collectibles-memorabilia-9/" rel="noopener '
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">收藏品及紀念品</p></a><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/travel-1945/" rel="noopener '
#  'noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo D_rC">旅行</p></a><a '
#  'class="D_xT M_wM D_Ey M_sg" href="/categories/sports-equipment-10/" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">運動產品</p></a><a class="D_xT M_wM D_Ey M_sg" '
#  'href="/categories/tickets-vouchers-18/" rel="noopener noreferrer" '
#  'target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo M_lO D_qr M_lR '
#  'D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">門票＆禮券</p></a></div></div></div></div></div><div class="D_RR '
#  'M_IW"></div><div class="D_RS M_IX"><div class="D_RT '
#  'M_IY"><div><div></div></div><p class="D_qk M_lK D_pN M_lC D_ql M_lL D_qo '
#  'M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_RX M_Jc D_rC">© <!-- -->2022<!-- --> '
#  'Carousell</p><div class="D_RY M_Je"><a class="D_Ey M_sg" '
#  'href="https://support.carousell.com/hc/zh-hk?origin=web&amp;platform=web" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">幫助中心</p></a><p aria-hidden="true" class="D_qk M_lK D_pP M_lF D_ql M_lL '
#  'D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rC">\xa0\n'
#  '          •\n'
#  '          \xa0</p><a class="D_Ey M_sg" '
#  'href="https://support.carousell.com/hc/zh-hk/requests/new?open_chat_bot=true&amp;origin=web&amp;platform=web" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">聯絡我哋</p></a><p aria-hidden="true" class="D_qk M_lK D_pP M_lF D_ql M_lL '
#  'D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rC">\xa0\n'
#  '          •\n'
#  '          \xa0</p><a class="D_Ey M_sg" href="https://press.carousell.com" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">媒體報導</p></a><p aria-hidden="true" class="D_qk M_lK D_pP M_lF D_ql M_lL '
#  'D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rC">\xa0\n'
#  '          •\n'
#  '          \xa0</p><a class="D_Ey M_sg" href="https://careers.carousell.com/" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">工作</p></a><p aria-hidden="true" class="D_qk M_lK D_pP M_lF D_ql M_lL '
#  'D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rC">\xa0\n'
#  '          •\n'
#  '          \xa0</p><a class="D_Ey M_sg" '
#  'href="https://docs.google.com/forms/d/1ZhprlP1FZ7Jk55RqlkAnT6YcV9DTDUoFM1gLCM59L6A/" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">廣告洽談</p></a><p aria-hidden="true" class="D_qk M_lK D_pP M_lF D_ql M_lL '
#  'D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rC">\xa0\n'
#  '          •\n'
#  '          \xa0</p><a class="D_Ey M_sg" '
#  'href="https://support.carousell.com/hc/zh-hk/articles/115011881808" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">條款</p></a><p aria-hidden="true" class="D_qk M_lK D_pP M_lF D_ql M_lL '
#  'D_qo M_lO D_qr M_lR D_qu M_lU D_qw M_lW D_rC">\xa0\n'
#  '          •\n'
#  '          \xa0</p><a class="D_Ey M_sg" '
#  'href="https://support.carousell.com/hc/zh-hk/articles/115006700307" '
#  'rel="noopener noreferrer" target="_blank"><p class="D_qk M_lK D_pN M_lC D_ql '
#  'M_lL D_qo M_lO D_qq M_lQ D_qu M_lU D_qw M_lW D_Cw D_Cr M_wo '
#  'D_rC">隱私政策</p></a></div></div><div class="D_RU M_IZ"><div '
#  'aria-label="Country select" class="D_RZ M_Jf"><a class="D_Ey M_sg" '
#  'href="https://au.carousell.com" rel="noopener noreferrer" '
#  'target="_blank"><img alt="Carousell Australia" class="D_ams M_Za D_Sa M_Jg" '
#  'style="height:24px;width:24px" loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/flag-au-1Vu2Ly0cBR.jpg"/></a><a '
#  'class="D_Ey M_sg" href="https://ca.carousell.com" rel="noopener noreferrer" '
#  'target="_blank"><img alt="Carousell Canada" class="D_ams M_Za D_Sa M_Jg" '
#  'style="height:24px;width:24px" loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/flag-ca-3zQT2z3CIo.jpg"/></a><a '
#  'class="D_Ey M_sg" href="https://www.carousell.com.hk" rel="noopener '
#  'noreferrer" target="_blank"><img alt="Carousell Hong Kong" class="D_ams M_Za '
#  'D_Sa M_Jg" style="height:24px;width:24px" loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/flag-hk-1Fq4xKBpW1.jpg"/></a><a '
#  'class="D_Ey M_sg" href="https://id.carousell.com" rel="noopener noreferrer" '
#  'target="_blank"><img alt="Carousell Indonesia" class="D_ams M_Za D_Sa M_Jg" '
#  'style="height:24px;width:24px" loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/flag-id-3hB56YEmaV.jpg"/></a><a '
#  'class="D_Ey M_sg" href="https://www.carousell.com.my" rel="noopener '
#  'noreferrer" target="_blank"><img alt="Carousell Malaysia" class="D_ams M_Za '
#  'D_Sa M_Jg" style="height:24px;width:24px" loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/flag-my-GKdsVkW7Qq.jpg"/></a><a '
#  'class="D_Ey M_sg" href="https://nz.carousell.com" rel="noopener noreferrer" '
#  'target="_blank"><img alt="Carousell New Zealand" class="D_ams M_Za D_Sa '
#  'M_Jg" style="height:24px;width:24px" loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/flag-nz-24qlj462lw.jpg"/></a><a '
#  'class="D_Ey M_sg" href="https://www.carousell.ph" rel="noopener noreferrer" '
#  'target="_blank"><img alt="Carousell Philippines" class="D_ams M_Za D_Sa '
#  'M_Jg" style="height:24px;width:24px" loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/flag-ph-cYUSK6Hapb.jpg"/></a><a '
#  'class="D_Ey M_sg" href="https://www.carousell.sg" rel="noopener noreferrer" '
#  'target="_blank"><img alt="Carousell Singapore" class="D_ams M_Za D_Sa M_Jg" '
#  'style="height:24px;width:24px" loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/flag-sg-3PPSOjFS5a.jpg"/></a><a '
#  'class="D_Ey M_sg" href="https://tw.carousell.com" rel="noopener noreferrer" '
#  'target="_blank"><img alt="Carousell Taiwan" class="D_ams M_Za D_Sa M_Jg" '
#  'style="height:24px;width:24px" loading="lazy" decoding="async" '
#  'src="https://mweb-cdn.karousell.com/build/flag-tw-6cZEDUfY6q.jpg"/></a></div><div '
#  'class="D_Sb M_Jh"><select aria-label="Language select" class="D_vi M_oE D_vk '
#  'D_vj" '
#  'style="background-image:https://mweb-cdn.karousell.com/build/arrow-drop-down-Z1FOB8HfVP.svg"><option '
#  'value="en">English</option><option value="zh-Hant-TW">繁體中文 '
#  '(台灣)</option><option selected="" value="zh-Hant-HK">繁體中文 '
#  '(香港)</option><option value="id">Bahasa '
#  'Indonesia</option></select></div></div></div></div></main><div class="D_rW '
#  'M_mq D_ss"></div></div></div>\n'
#  '    \n'
#  '    \n'
#  '    <script defer>\n'
#  '      window.performance && window.performance.mark("srtd-mark")\n'
#  '    </script>\n'
#  '    \n'
#  '    \n'
#  '    \n'
#  '    '
#  '<script>window.dataLayer=[{"loggedInStatus":"no"}];(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':new '
#  "Date().getTime(),event:'gtm.js'});var "
#  "f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=!0;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f)})(window,document,'script','dataLayer','GTM-KBXZNN7')</script>\n"
#  '    \n'
#  '    \n'
#  '  </body>\n'
#  '  <!--\n'
#  '    version: p-4b0e4dc\n'
#  '  -->\n'
#  '</html>')

# %%
user_href = re.match('href.*', searchResp.text)
pprint(user_href)
# Out:
# None
